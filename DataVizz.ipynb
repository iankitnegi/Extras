# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("bar_chart_data.csv")
df
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %%
plt.figure(figsize=(9,6))
plt.bar(df['Brand'], height=df['Cars Listings'])

plt.show()
